# %%
# Data manupulation and analysis
import pandas as pd
import numpy as np
import klib
import dtale
from pandas_profiling import ProfileReport

# Data visualization 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# Sklearn preprocessing
from sklearn.preprocessing import LabelEncoder

# Ignore Warnings
import warnings 
warnings.filterwarnings('always')
warnings.filterwarnings('ignore')

# %% [markdown]
# # The data scientists at BigMart have collected 2013 sales data for 1559 products across 10 stores in different cities. Also, certain attributes of each product and store have been defined. The aim is to build a predictive model and find out the sales of each product at a particular store. Using this model, BigMart will try to understand the properties of products and stores which play a key role in increasing sales.

# %% [markdown]
# # Data Collection

# %%
train = pd.read_csv('Train.csv')
test = pd.read_csv('Test.csv')

# %%
train.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
train.describe(include = 'all')
# Out:
#        Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# count             8523  7060.000000             8523      8523.000000
# unique            1559          NaN                5              NaN
# top              FDW13          NaN          Low Fat              NaN
# freq                10          NaN             5089              NaN
# mean               NaN    12.857645              NaN         0.066132
# std                NaN     4.643456              NaN         0.051598
# min                NaN     4.555000              NaN         0.000000
# 25%                NaN     8.773750              NaN         0.026989
# 50%                NaN    12.600000              NaN         0.053931
# 75%                NaN    16.850000              NaN         0.094585
# max                NaN    21.350000              NaN         0.328391
#
#                     Item_Type     Item_MRP Outlet_Identifier  \
# count                    8523  8523.000000              8523
# ...

# %%
train.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
test.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                   976
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  1606
# Outlet_Location_Type            0
# Outlet_Type                     0
# dtype: int64

# %% [markdown]
# # Missing Values Handling

# %%
train['Item_Weight'].fillna(train['Item_Weight'].mean(), inplace = True)
test['Item_Weight'].fillna(test['Item_Weight'].mean(), inplace = True)

# %%
train['Outlet_Size'].value_counts()
# Out:
# Medium    2793
# Small     2388
# High       932
# Name: Outlet_Size, dtype: int64

# %%
train['Outlet_Size'].fillna(train['Outlet_Size'].mode()[0], inplace = True)
test['Outlet_Size'].fillna(test['Outlet_Size'].mode()[0], inplace = True)

# %% [markdown]
# # Feature Selection

# %%
train.drop(['Item_Identifier','Outlet_Identifier'],axis= 1,  inplace  = True)
test.drop(['Item_Identifier','Outlet_Identifier'],axis= 1,  inplace  = True)

# %%
train.head()
# Out:
#    Item_Weight Item_Fat_Content  Item_Visibility              Item_Type  \
# 0         9.30          Low Fat         0.016047                  Dairy
# 1         5.92          Regular         0.019278            Soft Drinks
# 2        17.50          Low Fat         0.016760                   Meat
# 3        19.20          Regular         0.000000  Fruits and Vegetables
# 4         8.93          Low Fat         0.000000              Household
#
#    Item_MRP  Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0  249.8092                       1999      Medium               Tier 1
# 1   48.2692                       2009      Medium               Tier 3
# 2  141.6180                       1999      Medium               Tier 1
# 3  182.0950                       1998      Medium               Tier 3
# 4   53.8614                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1          3735.1380
# ...

# %%
test.head()
# Out:
#    Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  Item_MRP  \
# 0    20.750000          Low Fat         0.007565  Snack Foods  107.8622
# 1     8.300000              reg         0.038428        Dairy   87.3198
# 2    14.600000          Low Fat         0.099575       Others  241.7538
# 3     7.315000          Low Fat         0.015388  Snack Foods  155.0340
# 4    12.695633          Regular         0.118599        Dairy  234.2300
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2007      Medium               Tier 2
# 2                       1998      Medium               Tier 3
# 3                       2007      Medium               Tier 2
# 4                       1985      Medium               Tier 3
#
#          Outlet_Type
# 0  Supermarket Type1
# 1  Supermarket Type1
# 2      Grocery Store
# 3  Supermarket Type1
# 4  Supermarket Type3

# %% [markdown]
# # Exploratory Data Analysis

# %%
dtale.show(train)
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://DESKTOP-CDBDRMF:40000/dtale/iframe/1"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
profile = ProfileReport(train, title="Pandas Profiling Report")

# %%
profile
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v3.2.0&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content=&quot;2022-06-06 13:13:02.934846&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
plt.figure(figsize = (8,8))
sns.heatmap(train.corr(), annot = True)
plt.show()
# Out:
# 2022-06-06 18:43:18,218 - WARNING  - findfont: Font family ['Heiti TC'] not found. Falling back to DejaVu Sans.

# %%
- klib.cat_plot(train) # returns a visualization of the number and frequency of categorical features
# Out:
# 2022-06-06 18:43:19,059 - WARNING  - findfont: Font family ['Heiti TC'] not found. Falling back to DejaVu Sans.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_108/599648574.py in <module>
# ----> 1 - klib.cat_plot(train) # returns a visualization of the number and frequency of categorical features
#
# TypeError: bad operand type for unary -: 'GridSpec'
# 2022-06-06 18:43:20,522 - WARNING  - findfont: Font family ['Heiti TC'] not found. Falling back to DejaVu Sans.
# 2022-06-06 18:43:20,553 - WARNING  - findfont: Font family ['Heiti TC'] not found. Falling back to DejaVu Sans.

# %%
klib.corr_mat(train) # returns a color-encoded correlation matrix
# Out:
# <style type="text/css">
# #T_02ef1_row0_col0, #T_02ef1_row0_col2, #T_02ef1_row0_col4, #T_02ef1_row1_col1, #T_02ef1_row2_col0, #T_02ef1_row2_col2, #T_02ef1_row2_col3, #T_02ef1_row2_col4, #T_02ef1_row3_col2, #T_02ef1_row3_col3, #T_02ef1_row4_col0, #T_02ef1_row4_col2, #T_02ef1_row4_col4 {
#   color: None;
# }
# #T_02ef1_row0_col1, #T_02ef1_row0_col3, #T_02ef1_row1_col0, #T_02ef1_row1_col2, #T_02ef1_row1_col3, #T_02ef1_row1_col4, #T_02ef1_row2_col1, #T_02ef1_row3_col0, #T_02ef1_row3_col1, #T_02ef1_row3_col4, #T_02ef1_row4_col1, #T_02ef1_row4_col3 {
#   color: #FF3344;
# }
# </style>
# <table id="T_02ef1_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Item_Weight</th>
#       <th class="col_heading level0 col1" >Item_Visibility</th>
#       <th class="col_heading level0 col2" >Item_MRP</th>
#       <th class="col_heading level0 col3" >Outlet_Establishment_Year</th>
# ...

# %%
klib.corr_plot(train) # returns a color-encoded heatmap, ideal for correlations
# Out:
# <AxesSubplot:title={'center':'Feature-correlation (pearson)'}>

# %%
klib.dist_plot(train) # returns a distribution plot for every numeric feature
# Out:
# <AxesSubplot:xlabel='Item_Outlet_Sales', ylabel='Density'>

# %%
klib.missingval_plot(train) # returns a figure containing information about missing values
# Out:
# No missing values found in the dataset.

# %% [markdown]
# # Data Cleaning

# %%
klib.data_cleaning(train) # performs datacleaning (drop duplicates & empty rows/cols, adjust dtypes,...)
# Out:
# Shape of cleaned data: (8523, 10)Remaining NAs: 0
#
# Changes:
# Dropped rows: 0
#      of which 0 duplicates. (Rows: [])
# Dropped columns: 0
#      of which 0 single valued.     Columns: []
# Dropped missing values: 0
# Reduced memory by at least: 0.43 MB (-66.15%)
#       item_weight item_fat_content  item_visibility              item_type  \
# 0             9.3          Low Fat         0.016047                  Dairy
# 1            5.92          Regular         0.019278            Soft Drinks
# 2            17.5          Low Fat          0.01676                   Meat
# 3       19.200001          Regular              0.0  Fruits and Vegetables
# 4            8.93          Low Fat              0.0              Household
# ...           ...              ...              ...                    ...
# 8518        6.865          Low Fat         0.056783            Snack Foods
# 8519         8.38          Regular         0.046982           Baking Goods
# ...

# %%
klib.clean_column_names(train) # cleans and standardizes column names, also called inside data_cleaning()
# Out:
#       item_weight item_fat_content  item_visibility              item_type  \
# 0           9.300          Low Fat         0.016047                  Dairy
# 1           5.920          Regular         0.019278            Soft Drinks
# 2          17.500          Low Fat         0.016760                   Meat
# 3          19.200          Regular         0.000000  Fruits and Vegetables
# 4           8.930          Low Fat         0.000000              Household
# ...           ...              ...              ...                    ...
# 8518        6.865          Low Fat         0.056783            Snack Foods
# 8519        8.380          Regular         0.046982           Baking Goods
# 8520       10.600          Low Fat         0.035186     Health and Hygiene
# 8521        7.210          Regular         0.145221            Snack Foods
# 8522       14.800          Low Fat         0.044878            Soft Drinks
#
# ...

# %%
train = klib.convert_datatypes(train)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   item_weight                8523 non-null   Float32
#  1   item_fat_content           8523 non-null   category
#  2   item_visibility            8523 non-null   Float32
#  3   item_type                  8523 non-null   category
#  4   item_mrp                   8523 non-null   Float32
#  5   outlet_establishment_year  8523 non-null   int16
#  6   outlet_size                8523 non-null   category
#  7   outlet_location_type       8523 non-null   category
#  8   outlet_type                8523 non-null   category
#  9   item_outlet_sales          8523 non-null   Float32
# dtypes: Float32(4), category(5), int16(1)
# memory usage: 226.2 KB

# %% [markdown]
# # Preprocessing before building our model

# %% [markdown]
# # 1) Label Encoding

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   item_weight                8523 non-null   Float32
#  1   item_fat_content           8523 non-null   category
#  2   item_visibility            8523 non-null   Float32
#  3   item_type                  8523 non-null   category
#  4   item_mrp                   8523 non-null   Float32
#  5   outlet_establishment_year  8523 non-null   int16
#  6   outlet_size                8523 non-null   category
#  7   outlet_location_type       8523 non-null   category
#  8   outlet_type                8523 non-null   category
#  9   item_outlet_sales          8523 non-null   Float32
# dtypes: Float32(4), category(5), int16(1)
# memory usage: 226.2 KB

# %%
train.describe(include = 'all')
# Out:
#         item_weight item_fat_content  item_visibility              item_type  \
# count   8523.000000             8523      8523.000000                   8523
# unique          NaN                5              NaN                     16
# top             NaN          Low Fat              NaN  Fruits and Vegetables
# freq            NaN             5089              NaN                   1232
# mean      12.857646              NaN         0.066132                    NaN
# std        4.226124              NaN         0.051598                    NaN
# min        4.555000              NaN         0.000000                    NaN
# 25%        9.310000              NaN         0.026989                    NaN
# 50%       12.857645              NaN         0.053931                    NaN
# 75%       16.000000              NaN         0.094585                    NaN
# max       21.350000              NaN         0.328391                    NaN
#
# ...

# %%
le = LabelEncoder()

# %%
le
# Out:
# LabelEncoder()

# %%
train['item_fat_content'].value_counts()
# Out:
# Low Fat    5089
# Regular    2889
# LF          316
# reg         117
# low fat     112
# Name: item_fat_content, dtype: int64

# %%
# Combine fat content
train['item_fat_content']=train['item_fat_content'].replace({'LF':'Low Fat','reg':'Regular','low fat':'Low Fat'})

# %%
train['item_fat_content'].value_counts()
# Out:
# Low Fat    5517
# Regular    3006
# Name: item_fat_content, dtype: int64
# Executing shutdown due to inactivity...
# 2022-06-06 19:43:05,900 - INFO     - Executing shutdown due to inactivity...
# Executing shutdown...
# 2022-06-06 19:43:18,292 - INFO     - Executing shutdown...
